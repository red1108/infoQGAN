# %%
dirs = [
    ["./iris_runs/IRIS_GAN_sd0.8_code2_Mar13_22_53_07/numpy/gen_outputs_epoch_237.txt", "GAN"],
    ["./iris_runs/IRIS_InfoGAN_sd0.8_code2_Mar13_22_52_59/numpy/gen_outputs_epoch_237.txt", "InfoGAN"]
]
# load datas
# Out:
# hi
